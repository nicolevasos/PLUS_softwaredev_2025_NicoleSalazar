# %%
from matplotlib import pyplot as plt
import numpy as np
# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()
# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import test.py
# Out:
# ['', '/opt/homebrew/Cellar/gdal/3.10.0/lib/python3.9/site-packages', '/Users/nicolesalazar/Documents/MASTER/CDE/S2/PSD/repos/PLUS_softwaredev_2025_NicoleSalazar', '/Users/nicolesalazar/anaconda3/lib/python38.zip', '/Users/nicolesalazar/anaconda3/lib/python3.8', '/Users/nicolesalazar/anaconda3/lib/python3.8/lib-dynload', '/Users/nicolesalazar/.local/lib/python3.8/site-packages', '/Users/nicolesalazar/anaconda3/lib/python3.8/site-packages', '/Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/aeosa', '/Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/setuptools/_vendor']
#
# Please wait a moment while I gather a list of all available modules...
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/pkgutil.py:92: NumbaPendingDeprecationWarning: The 'pycc' module is pending deprecation. Replacement technology is being developed.
#
# Pending Deprecation in Numba 0.57.0. For more information please see: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-the-numba-pycc-module
#   __import__(info.name)
# /Users/nicolesalazar/anaconda3/lib/python3.8/pkgutil.py:92: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/_distutils_hack/__init__.py:31: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# /Users/nicolesalazar/anaconda3/lib/python3.8/site-packages/spaghetti/network.py:40: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(dep_msg, FutureWarning, stacklevel=1)
